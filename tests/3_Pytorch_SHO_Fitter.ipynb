# %% [markdown]
# # 3. SHO Fitting in Pytorch

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from m3util.viz.printing import printer
from m3util.viz.style import set_style
from m3util.ml.rand import set_seeds
from m3util.util.IO import download_and_unzip
from belearn.dataset.dataset import BE_Dataset
from belearn.viz.viz import Viz
from belearn.functions.sho import SHO_nn
from belearn.dataset.analytics import print_mse
from autophyslearn.postprocessing.complex import ComplexPostProcessor
from autophyslearn.spectroscopic.nn import Multiscale1DFitter, Model


printing = printer(basepath = './Figures/')


set_style("printing")
set_seeds(seed=42)

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# printing set for seaborn
# Pytorch seed was set to 42
# Numpy seed was set to 42
# tensorflow seed was set to 42

# %% [markdown]
# ## Loads Data

# %%
# Specify the filename and the path to save the file
filename = 'data_raw.h5'
save_path = "./Data"

data_path = save_path + "/" + filename

# %%
# instantiate the dataset object
dataset = BE_Dataset(data_path, SHO_fit_func_LSQF=SHO_nn)

# print the contents of the file
dataset.print_be_tree()
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Noisy_Data_1
#     ├ Noisy_Data_2
#     ├ Noisy_Data_3
#     ├ Noisy_Data_4
#     ├ Noisy_Data_5
#     ├ Noisy_Data_6
#     ├ Noisy_Data_7
#     ├ Noisy_Data_8
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ UDVS
#     ├ UDVS_Indices
# ├ Noisy_Data_1_SHO_Fit
#   --------------------
#   ├ Noisy_Data_1-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_2_SHO_Fit
#   --------------------
#   ├ Noisy_Data_2-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_3_SHO_Fit
#   --------------------
#   ├ Noisy_Data_3-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_4_SHO_Fit
#   --------------------
#   ├ Noisy_Data_4-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_5_SHO_Fit
#   --------------------
#   ├ Noisy_Data_5-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_6_SHO_Fit
#   --------------------
#   ├ Noisy_Data_6-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_7_SHO_Fit
#   --------------------
#   ├ Noisy_Data_7-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_8_SHO_Fit
#   --------------------
#   ├ Noisy_Data_8-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Raw_Data_SHO_Fit
#   ----------------
#   ├ Raw_Data-SHO_Fit_000
#     --------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# Datasets and datagroups within the file:
# ------------------------------------
# /
# /Measurement_000
# /Measurement_000/Channel_000
# /Measurement_000/Channel_000/Bin_FFT
# /Measurement_000/Channel_000/Bin_Frequencies
# /Measurement_000/Channel_000/Bin_Indices
# /Measurement_000/Channel_000/Bin_Step
# /Measurement_000/Channel_000/Bin_Wfm_Type
# /Measurement_000/Channel_000/Excitation_Waveform
# /Measurement_000/Channel_000/Noise_Floor
# /Measurement_000/Channel_000/Noisy_Data_1
# /Measurement_000/Channel_000/Noisy_Data_2
# /Measurement_000/Channel_000/Noisy_Data_3
# /Measurement_000/Channel_000/Noisy_Data_4
# /Measurement_000/Channel_000/Noisy_Data_5
# /Measurement_000/Channel_000/Noisy_Data_6
# /Measurement_000/Channel_000/Noisy_Data_7
# /Measurement_000/Channel_000/Noisy_Data_8
# /Measurement_000/Channel_000/Position_Indices
# /Measurement_000/Channel_000/Position_Values
# /Measurement_000/Channel_000/Raw_Data
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Step_Averaged_Response
# /Measurement_000/Channel_000/Spectroscopic_Indices
# /Measurement_000/Channel_000/Spectroscopic_Values
# /Measurement_000/Channel_000/UDVS
# /Measurement_000/Channel_000/UDVS_Indices
# /Noisy_Data_1_SHO_Fit
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Fit
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Guess
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_2_SHO_Fit
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Fit
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Guess
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_3_SHO_Fit
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Fit
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Guess
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_4_SHO_Fit
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Fit
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Guess
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_5_SHO_Fit
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Fit
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Guess
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_6_SHO_Fit
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Fit
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Guess
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_7_SHO_Fit
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Fit
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Guess
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_8_SHO_Fit
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Fit
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Guess
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/completed_guess_positions
# /Raw_Data_SHO_Fit
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Fit
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Guess
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Spectroscopic_Indices
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Spectroscopic_Values
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/completed_fit_positions
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/completed_guess_positions
#
# The main dataset:
# ------------------------------------
# <HDF5 file "data_raw.h5" (mode r+)>
#
# The ancillary datasets:
# ------------------------------------
# <HDF5 dataset "Position_Indices": shape (3600, 2), type "<u4">
# <HDF5 dataset "Position_Values": shape (3600, 2), type "<f4">
# <HDF5 dataset "Spectroscopic_Indices": shape (4, 63360), type "<u4">
# <HDF5 dataset "Spectroscopic_Values": shape (4, 63360), type "<f4">
#
# Metadata or attributes in a datagroup
# ------------------------------------
# BE_actual_duration_[s] : 0.004
# BE_amplitude_[V] : 1
# BE_auto_smoothing : auto smoothing on
# BE_band_edge_smoothing_[s] : 4832.1
# BE_band_edge_trim : 0.094742
# BE_band_width_[Hz] : 200000
# BE_bins_per_band : 0
# BE_center_frequency_[Hz] : 1310000
# BE_desired_duration_[s] : 0.004
# BE_phase_content : chirp-sinc hybrid
# BE_phase_variation : 1
# BE_points_per_BE_wave : 0
# BE_repeats : 4
# FORC_V_high1_[V] : 1
# FORC_V_high2_[V] : 10
# FORC_V_low1_[V] : -1
# FORC_V_low2_[V] : -10
# FORC_num_of_FORC_cycles : 1
# FORC_num_of_FORC_repeats : 1
# File_MDAQ_version : MDAQ_VS_090915_01
# File_date_and_time : 18-Sep-2015 18:32:14
# File_file_name : SP128_NSO
# File_file_path : C:\Users\Asylum User\Documents\Users\Agar\SP128_NSO\
# File_file_suffix : 99
# IO_AO_amplifier : 10
# IO_AO_range_[V] : +/- 10
# IO_Analog_Input_1 : +/- .1V, FFT
# IO_Analog_Input_2 : off
# IO_Analog_Input_3 : off
# IO_Analog_Input_4 : off
# IO_DAQ_platform : NI 6115
# IO_rate_[Hz] : 4000000
# VS_amplitude_[V] : 16
# VS_cycle_fraction : full
# VS_cycle_phase_shift : 0
# VS_measure_in_field_loops : in and out-of-field
# VS_mode : DC modulation mode
# VS_number_of_cycles : 2
# VS_offset_[V] : 0
# VS_read_voltage_[V] : 0
# VS_set_pulse_amplitude[V] : 0
# VS_set_pulse_duration[s] : 0.002
# VS_step_edge_smoothing_[s] : 0.001
# VS_steps_per_full_cycle : 96
# data_type : BEPSData
# grid_/single : grid
# grid_contact_set_point_[V] : 1
# grid_current_col : 1
# grid_current_row : 1
# grid_cycle_time_[s] : 10
# grid_measuring : 0
# grid_moving : 0
# grid_num_cols : 60
# grid_num_rows : 60
# grid_settle_time_[s] : 0.15
# grid_time_remaining_[h;m;s] : 10
# grid_total_time_[h;m;s] : 10
# grid_transit_set_point_[V] : 0.1
# grid_transit_time_[s] : 0.15
# num_bins : 165
# num_pix : 3600
# num_udvs_steps : 384

# %% [markdown]
# ## Testing the Torch Function
#
# The function for a simple-harmonic oscillator needs to be recast in PyTorch. Here we prove that the PyTorch function is implemented identically to the Numpy model.
#
# Note: This uses the results from the least squares fitting LSQF results.

# %%
# insatiate the visualization object
image_scalebar = [2000, 500, "nm", "br"]

BE_viz = Viz(dataset, printing, verbose=True, 
             SHO_ranges = [(0,1.5e-4), (1.31e6, 1.33e6), (-300, 0), (-np.pi, np.pi)],
             image_scalebar=image_scalebar)

# %%
true = {"resampled": False,
        "label": "Raw",
        "noise": 0, 
        "measurement_state": "all"}

predicted = {"fitter": "LSQF", "resampled": False, "label": "Raw", "scaled": False, "noise" : 0}

BE_viz.fit_tester(true, predicted, filename="Figure_7_PyTorch_fit_tester")
# Out:
# {'resampled': False, 'label': 'Raw', 'noise': 0, 'measurement_state': 'all'}
# True
#
#
#         Dataset = Raw_Data
#         Resample = False
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = False
#         Resample Bins = 165
#         LSQF Phase Shift = None
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# predicted
#
#
#         Dataset = Raw_Data
#         Resample = False
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = False
#         Resample Bins = 165
#         LSQF Phase Shift = None
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# ./Figures/Figure_7_PyTorch_fit_tester.png
# ./Figures/Figure_7_PyTorch_fit_tester.svg

# %% [markdown]
# **Figure 3.1** Shows the result of the PyTorch function. The result based on the LSQF results shows that the PyTorch function is implemented correctly.

# %% [markdown]
# ## Pytorch Model
#
# ### Model Architecture

# %% [markdown]
# ### Scaling the Data
#
# When training the neural network it is useful to scale the data. We apply a global scaler such that the spectrum have a mean of 0 and a standard deviation of 1.
#
# #### Visualizing the Scaled Data

# %%
state = {"fitter": "LSQF", "resampled": True, "scaled": True, "label": "Scaled"}

BE_viz.nn_checker(state, filename="Figure_8_Scaled Raw Data")
# Out:
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = None
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# ./Figures/Figure_8_Scaled Raw Data.png
# ./Figures/Figure_8_Scaled Raw Data.svg

# %% [markdown]
# **Figure 3.2** shows the scaled data. The data is scaled to have a mean of 0 and a standard deviation of 1. This is done using a global scaler of the entire spectrum.

# %%
dataset.LSQF_phase_shift = np.pi / 2

BE_viz.SHO_hist(
    dataset.SHO_fit_results(), filename="Figure_9_Phase_Shifted_Scaled_Histograms"
)
# Out:
# current_SHO_ranges: [(0, 0.00015), (1310000.0, 1330000.0), (-300, 0), (-3.141592653589793, 3.141592653589793)]
# current_dataset_state: {'raw_format': 'complex', 'fitter': 'LSQF', 'scaled': False, 'output_shape': 'pixels', 'measurement_state': 'all', 'LSQF_phase_shift': 1.5707963267948966, 'NN_phase_shift': None, 'noise': 0, 'loop_interpolated': False}
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# ./Figures/Figure_9_Phase_Shifted_Scaled_Histograms.png
# ./Figures/Figure_9_Phase_Shifted_Scaled_Histograms.svg

# %% [markdown]
# **Figure 3.3** shows the histograms of the scaled a) amplitude, b) resonance frequency, c) quality factor, and d) phase. These are approximated from the LSQF. These are the scaled values that are predicted by the neural network. Note there is a transformation applied to the phase.

# %% [markdown]
# ### Training the Model
#
# We will train the model from scratch. Generally the model trains very well in a few epochs. This will take less than 5 minutes to train on a GPU.

# %%
set_seeds(seed=42)

postprocessor = ComplexPostProcessor(dataset)

model_ = Multiscale1DFitter(SHO_nn, # function 
                            dataset.frequency_bin, # x data
                            2, # input channels
                            4, # output channels
                            dataset.SHO_scaler, 
                            postprocessor)

# instantiate the model
model = Model(model_, dataset, training=True, model_basename="SHO_Fitter_original_data")
# Out:
# Pytorch seed was set to 42
# Numpy seed was set to 42
# tensorflow seed was set to 42
# Using GPU NVIDIA GeForce RTX 3090

# %%
# constructs a test train split
X_train, X_test, y_train, y_test = dataset.test_train_split_(shuffle=True)
# Out:
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# None

# %%
train = True

if train:
    # fits the model
    model.fit(
        dataset.X_train,
        500,
        optimizer="Adam",
        epochs = 5,
    )
else:
    model.load(
        "/home/ferroelectric/m3_learning/m3_learning/papers/2023_Rapid_Fitting/Trained Models/SHO Fitter/SHO_Fitter_original_data_model_epoch_5_train_loss_0.0449272525189978.pth"
    )
# Out:
# Pytorch seed was set to 42
# Numpy seed was set to 42
# tensorflow seed was set to 42
# /home/ferroelectric/.local/lib/python3.8/site-packages/torch/autograd/graph.py:769: UserWarning: Using backward() with create_graph=True will create a reference cycle between the parameter and its gradient which can cause a memory leak. We recommend using autograd.grad when creating the graph to avoid this. If you have to use this function, make sure to reset the .grad fields of your parameters to None after use to break the cycle and avoid the leak. (Triggered internally at ../torch/csrc/autograd/engine.cpp:1203.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Adam
# epoch : 1/5, recon loss = 0.06532227
# --- 19.191284894943237 seconds ---
# Epoch 1, Learning Rate: 0.001
# Adam
# epoch : 2/5, recon loss = 0.03466978
# --- 18.575798511505127 seconds ---
# Epoch 2, Learning Rate: 0.001
# Adam
# epoch : 3/5, recon loss = 0.03431491
# --- 18.443825244903564 seconds ---
# Epoch 3, Learning Rate: 0.001
# Adam
# epoch : 4/5, recon loss = 0.03413322
# --- 18.373677730560303 seconds ---
# Epoch 4, Learning Rate: 0.001
# Adam
# epoch : 5/5, recon loss = 0.03407400
# --- 18.42067551612854 seconds ---
# Epoch 5, Learning Rate: 0.001

# %% [markdown]
# ### Evaluate the Neural Network Results
#
# It is always recommended to validate that the autoencoder is working correctly. We can do this by comparing the different stages of the autoencoder including the raw data, the generated curves.

# %%
d1, d2, index1, mse1 = BE_viz.bmw_nn(
    X_train,
    prediction=model,
    out_state={"scaled": True, "raw_format": "complex"},
    returns=True,
    filename="Figure_10_NN_validation_Train",
)
# Out:
# ./Figures/Figure_10_NN_validation_Train.png
# ./Figures/Figure_10_NN_validation_Train.svg

# %% [markdown]
# **Figure 3.4** Raw data and reconstruction of the autoendcoder for the training data. Shows the a) best, b) median, and c) worst reconstruction of the training data.

# %%
d1, d2, index1, mse1 = BE_viz.bmw_nn(
    X_test,
    prediction=model,
    out_state={"scaled": True, "measurement State": "complex"},
    returns=True,
    filename="Figure_11_NN_validation_test",
)
# Out:
# ./Figures/Figure_11_NN_validation_test.png
# ./Figures/Figure_11_NN_validation_test.svg

# %% [markdown]
# **Figure 3.5** Raw data and reconstruction of the autoendcoder for the test data. Shows the a) best, b) median, and c) worst reconstruction of the test data.

# %%
state = {
    "fitter": "LSQF",
    "raw_format": "complex",
    "resampled": False,
    "scaled": True,
    "output_shape": "index",
}

X_data, Y_data = dataset.NN_data()

d1, d2, index1, mse1 = BE_viz.bmw_nn(
    state,
    prediction=model,
    out_state={"scaled": True, "measurement State": "complex"},
    returns=True,
    filename="Figure_12_NN_validation_full_data",
)
# Out:
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
# ./Figures/Figure_12_NN_validation_full_data.png
# ./Figures/Figure_12_NN_validation_full_data.svg

# %% [markdown]
# **Figure 3.6** Raw data and reconstruction of the autoendcoder for the entire data. Shows the a) best, b) median, and c) worst reconstruction of the entire data.

# %% [markdown]
# ### Calculate the MSE error
#
# We can calculate the MSE error for the training, test, and entire data set.

# %%
X_data, Y_data = dataset.NN_data()
LSQF_ = {'resampled': True,
                'raw_format': 'complex',
                'fitter': 'LSQF',
                'scaled': True,
                'output_shape': 'index',
                'measurement_state': 'all',
                'resampled_bins': 165,
                'LSQF_phase_shift': 1.5707963267948966,
                'NN_phase_shift': None,
                'noise': 0}

data = (LSQF_, X_data, X_test, X_train)
labels = ["LSQF", "Full Data", "Test Data", "Train Data"]

print_mse(model_, model, data, labels)
# Out:
#         Dataset = Raw_Data
#         Resample = False
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = False
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
# LSQF Mean Squared Error: 0.0344539
# Full Data Mean Squared Error: 0.0338586
# Test Data Mean Squared Error: 0.0338496
# Train Data Mean Squared Error: 0.0338609

# %% [markdown]
# From here on out we will assume that the autoencoder is working correctly, and is not overfit. This is a good assumption because the results are more or less the same for the training, test, and entire data set.
#
# We note that the MSE error is not a true indicator that the model is doing a better job extracting the physics parameters of the data.

# %% [markdown]
# ### GPU Inference Speedtest
#
# Here we show the speedtest for the GPU. This is done using the torch.cuda.synchronize() function. This is used to ensure that the GPU is done processing before the timer is stopped.

# %%
X_data, Y_data = dataset.NN_data()

model.inference_timer(X_data, batch_size=1000)
# Out:
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = None
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
# Mean execution time computed for 1383 batches of size 1000
# Average execution time per batch (ms): 1.714529 ± 0.666167
# Average execution time per iteration (ms): 0.001715 ± 0.000666
# Total execution time (s): 2.37

# %% [markdown]
# ### Histogram of Fit Results
#
# It is useful to view the histogram of the fitting results to apply any necessary phase shifts, and to see if the results are reasonable.

# %%
# we will add the appropriate phase shift to the dataset based on the fix seed,
# If your seed is different the results might vary
dataset.NN_phase_shift = np.pi/2 

# you can view the test and training dataset by replacing X_data with X_test or X_train
pred_data, scaled_param, parm = model.predict(X_data)

BE_viz.SHO_hist(parm, filename="Figure_13_NN_Unscaled_Parameters_Histograms")
# Out:
# current_SHO_ranges: [(0, 0.00015), (1310000.0, 1330000.0), (-300, 0), (-3.141592653589793, 3.141592653589793)]
# current_dataset_state: {'raw_format': 'complex', 'fitter': 'LSQF', 'scaled': False, 'output_shape': 'pixels', 'measurement_state': 'all', 'LSQF_phase_shift': 1.5707963267948966, 'NN_phase_shift': 1.5707963267948966, 'noise': 0, 'loop_interpolated': False}
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# ./Figures/Figure_13_NN_Unscaled_Parameters_Histograms.png
# ./Figures/Figure_13_NN_Unscaled_Parameters_Histograms.svg

# %% [markdown]
# **Figure 3.7** Histogram of the fit results for the a) amplitude, b) resonance frequency, c) quality factor, and d) phase.

# %%
out = dataset.SHO_scaler.transform(parm)

BE_viz.SHO_hist(out, filename="Figure_13_NN_scaled_Parameters_Histograms", scaled=True)
# Out:
# current_SHO_ranges: [(0, 0.00015), (1310000.0, 1330000.0), (-300, 0), (-3.141592653589793, 3.141592653589793)]
# current_dataset_state: {'raw_format': 'complex', 'fitter': 'LSQF', 'scaled': False, 'output_shape': 'pixels', 'measurement_state': 'all', 'LSQF_phase_shift': 1.5707963267948966, 'NN_phase_shift': 1.5707963267948966, 'noise': 0, 'loop_interpolated': False}
# dataset is scaled
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# ./Figures/Figure_13_NN_scaled_Parameters_Histograms.png
# ./Figures/Figure_13_NN_scaled_Parameters_Histograms.svg

# %% [markdown]
# **Figure 3.8** Histogram of the fit results for the a) amplitude, b) resonance frequency, c) quality factor, and d) phase. The histograms show the scaled parameters.

# %%
# you can view the test and training dataset by replacing X_data with X_test or X_train
pred_data, scaled_param, parm = model.predict(X_data)

BE_viz.SHO_switching_maps(parm, filename="Figure_15_NN_Switching_Maps")
# Out:
# ./Figures/Figure_15_NN_Switching_Maps.png
# ./Figures/Figure_15_NN_Switching_Maps.svg
# /home/ferroelectric/BEPiezo-Learn/src/belearn/viz/viz.py:1065: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# **Figure 3.9** Snapshots of the amplitude, resonance frequency, quality factor, and phase of the piezoresponse during ferroelectric switching.

# %% [markdown]
# ## SHO Fitting Movies

# %%
# Insatiate the visualization object
image_scalebar = [2000, 500, "nm", "br"]

BE_viz = Viz(dataset, printing, verbose=True, 
             SHO_ranges = [(0,1.5e-4), (1.31e6, 1.33e6), (-300, 0), (-np.pi, np.pi)],
             image_scalebar=image_scalebar)

# %%
BE_viz.SHO_fit_movie_images(noise = 0, 
                            models = [model],
                            scalebar_= True, 
                            basepath = "Movies/SHO_NN_",  
                            filename="SHO_NN",
                            phase_shift = [np.pi/2],)
# Out:
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = on
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = off
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0000.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0001.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0002.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0003.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0004.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0005.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0006.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0007.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0008.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0009.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0010.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0011.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0012.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0013.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0014.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0015.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0016.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0017.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0018.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0019.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0020.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0021.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0022.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0023.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0024.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0025.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0026.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0027.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0028.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0029.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0030.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0031.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0032.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0033.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0034.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0035.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0036.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0037.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0038.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0039.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0040.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0041.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0042.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0043.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0044.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0045.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0046.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0047.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0048.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0049.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0050.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0051.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0052.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0053.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0054.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0055.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0056.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0057.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0058.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0059.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0060.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0061.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0062.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0063.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0064.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0065.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0066.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0067.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0068.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0069.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0070.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0071.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0072.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0073.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0074.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0075.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0076.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0077.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0078.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0079.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0080.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0081.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0082.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0083.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0084.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0085.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0086.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0087.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0088.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0089.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0090.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0091.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0092.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0093.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0094.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0095.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0096.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0097.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0098.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0099.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0100.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0101.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0102.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0103.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0104.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0105.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0106.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0107.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0108.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0109.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0110.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0111.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0112.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0113.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0114.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0115.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0116.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0117.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0118.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0119.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0120.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0121.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0122.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0123.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0124.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0125.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0126.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0127.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0128.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0129.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0130.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0131.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0132.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0133.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0134.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0135.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0136.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0137.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0138.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0139.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0140.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0141.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0142.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0143.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0144.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0145.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0146.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0147.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0148.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0149.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0150.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0151.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0152.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0153.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0154.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0155.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0156.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0157.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0158.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0159.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0160.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0161.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0162.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0163.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0164.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0165.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0166.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0167.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0168.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0169.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0170.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0171.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0172.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0173.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0174.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0175.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0176.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0177.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0178.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0179.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0180.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0181.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0182.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0183.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0184.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0185.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0186.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0187.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0188.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0189.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0190.png
# Movies/SHO_NN_Noise_0/SHO_NN_noise_0_0191.png
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 192/192 [00:26<00:00,  7.29it/s]

# %% [markdown]
# ## Comparison SHO and Neural Network Fits
#
# 3 graphs, best, median, worst
#
# histograms of parameters.

# %%
# sets the phase shift of the dataset
dataset.NN_phase_shift = np.pi/2
dataset.LSQF_phase_shift = np.pi/2
dataset.measurement_state = "all"

# sets the true state which to compare the results.
true_state = {
    "fitter": "LSQF",
    "raw_format": "complex",
    "resampled": True,
    "scaled": True,
    "output_shape": "index",
    "measurement_state": "all",
}

# sets the state of the output data
out_state = {"scaled": True, "raw_format": "magnitude spectrum"}

# sets the number of examples to get
n = 1

LSQF = BE_viz.get_best_median_worst(
    true_state,
    prediction={"fitter": "LSQF"},
    out_state=out_state,
    SHO_results=True,
    n=n,
)

NN = BE_viz.get_best_median_worst(
    true_state, prediction=model, out_state=out_state, SHO_results=True, n=n
)

data = (LSQF, NN)
names = ["LSQF", "NN"]

BE_viz.SHO_Fit_comparison(
    data,
    names,
    model_comparison=[model, {"fitter": "LSQF"}],
    out_state=out_state,
    filename="Figure_14_LSQF_NN_bmw_comparison",
    verbose=False,
)
# Out:
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = True
#         Output Shape = index
#         Measurement State = all
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
# ./Figures/Figure_14_LSQF_NN_bmw_comparison.png
# ./Figures/Figure_14_LSQF_NN_bmw_comparison.svg

# %% [markdown]
# **Figure 3.10** Comparison of the a,b) best , c,d) median, and e,f) worst simple harmonic oscillator fits. a,c,e) are based on the fit results from the simple harmonic oscillator model, wherein b,d,f) are based on the neural network model. Generally speaking, all fits are good for both models on the as collected data.

# %% [markdown]
# ### Statistics of the Results for Training, Validation, and Entire Dataset

# %%
true_state = {
    "fitter": "LSQF",
    "raw_format": "complex",
    "resampled": True,
    "scaled": True,
    "output_shape": "index",
    "measurement_state": "all",
}


BE_viz.violin_plot_comparison_SHO(true_state, model, X_data, filename="Figure_16_Violin")
# Out:
# ./Figures/Figure_16_Violin.png
# ./Figures/Figure_16_Violin.svg

# %% [markdown]
# **Figure 3.11** Violin plot showing the difference in the distribution for the fit results for the LSQF algorithm show in blue, and the NN shown in orange.

# %% [markdown]
# ### SHO Comparison Movie

# %%
BE_viz.SHO_fit_movie_images(noise = 0, 
                            models=[None, model], 
                            scalebar_= True, 
                            basepath = "Movies/SHO_NN_LSQF_Compare_",  
                            filename="SHO_NN_LSQF_Compare", 
                            labels = ['LSQF', 'NN'],
                            phase_shift = [np.pi/2, np.pi/2])
# Out:
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = on
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
#
#         Dataset = Raw_Data
#         Resample = True
#         Raw Format = complex
#         Fitter = LSQF
#         Scaled = False
#         Output Shape = pixels
#         Measurement State = off
#         Resample Resampled = True
#         Resample Bins = 165
#         LSQF Phase Shift = 1.5707963267948966
#         NN Phase Shift = 1.5707963267948966
#         Noise Level = 0
#         Loop Interpolated = False
#
# None
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0000.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0001.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0002.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0003.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0004.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0005.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0006.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0007.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0008.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0009.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0010.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0011.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0012.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0013.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0014.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0015.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0016.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0017.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0018.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0019.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0020.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0021.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0022.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0023.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0024.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0025.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0026.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0027.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0028.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0029.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0030.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0031.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0032.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0033.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0034.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0035.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0036.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0037.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0038.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0039.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0040.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0041.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0042.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0043.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0044.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0045.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0046.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0047.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0048.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0049.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0050.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0051.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0052.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0053.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0054.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0055.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0056.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0057.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0058.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0059.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0060.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0061.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0062.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0063.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0064.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0065.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0066.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0067.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0068.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0069.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0070.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0071.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0072.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0073.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0074.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0075.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0076.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0077.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0078.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0079.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0080.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0081.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0082.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0083.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0084.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0085.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0086.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0087.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0088.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0089.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0090.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0091.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0092.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0093.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0094.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0095.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0096.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0097.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0098.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0099.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0100.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0101.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0102.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0103.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0104.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0105.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0106.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0107.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0108.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0109.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0110.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0111.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0112.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0113.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0114.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0115.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0116.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0117.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0118.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0119.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0120.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0121.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0122.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0123.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0124.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0125.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0126.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0127.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0128.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0129.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0130.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0131.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0132.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0133.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0134.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0135.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0136.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0137.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0138.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0139.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0140.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0141.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0142.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0143.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0144.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0145.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0146.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0147.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0148.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0149.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0150.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0151.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0152.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0153.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0154.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0155.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0156.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0157.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0158.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0159.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0160.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0161.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0162.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0163.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0164.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0165.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0166.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0167.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0168.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0169.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0170.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0171.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0172.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0173.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0174.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0175.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0176.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0177.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0178.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0179.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0180.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0181.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0182.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0183.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0184.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0185.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0186.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0187.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0188.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0189.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0190.png
# Movies/SHO_NN_LSQF_Compare_Noise_0/SHO_NN_LSQF_Compare_noise_0_0191.png
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 192/192 [01:28<00:00,  2.18it/s]

# %% [markdown]
# ### Outliers Visualization
#
# Resonance outliers

# %%
dataset.measurement_state = "all"
dataset.NN_phase_shift = np.pi/2
dataset.LSQF_phase_shift = np.pi/2

true_state = {
    "fitter": "LSQF",
    "raw_format": "complex",
    "resampled": True,
    "scaled": True,
    "output_shape": "index",
    "measurement_state": "all",
}

# gets the parameters from the SHO LSQF fit
true = dataset.SHO_fit_results(state = true_state).reshape(-1, 4)

# finds the index less than a certain value
ind = np.argwhere(true[:,1]< -3).flatten()


true_state = {
    "fitter": "LSQF",
    "raw_format": "complex",
    "resampled": True,
    "scaled": True,
    "output_shape": "index",
    "measurement_state": "all"
}

out_state = {"raw_format": "magnitude spectrum", "measurement_state": "all"}

n = 1

LSQF = BE_viz.get_best_median_worst(
    true_state,
    prediction={"fitter": "LSQF"},
    out_state=out_state,
    SHO_results=True,
    n=n,
    index = ind,
    verbose = False
)

NN = BE_viz.get_best_median_worst(
    true_state, prediction=model,
    out_state=out_state, SHO_results=True, n=n, index = ind, verbose = False,
)

data = (LSQF, NN)
names = ["LSQF", "NN"]

BE_viz.SHO_Fit_comparison(
    data,
    names,
    model_comparison=[model, {"fitter": "LSQF"}],
    out_state=out_state,
    filename="Figure_14_LSQF_NN_bmw_comparison",
    verbose = False
)
# Out:
# ./Figures/Figure_14_LSQF_NN_bmw_comparison.png
# ./Figures/Figure_14_LSQF_NN_bmw_comparison.svg

# %% [markdown]
# **Figure 3.12** One thing that was noticed was the LSQF results showed outliers for the Resonance. We find all values from the outlier distribtion from the LSQF, and plot the comparison of the a,b) best , c,d) median, and e,f) worst simple harmonic oscillator fits. a,c,e) are based on the fit results from the simple harmonic oscillator model, wherein b,d,f) are based on the neural network model. The neural network performs better in this distribution. It is worth noting that the best response is obtained when the amplitude, and thus the error, is small.
