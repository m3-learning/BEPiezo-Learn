# %% [markdown]
# ### Import the necessary packages

# %%
import sys

sys.path.append("../../")

from dataset_new import BE_Dataset
from m3util.util.IO import download_and_unzip

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Load the h5 file

# %%
# Download the data file from Zenodo
url = 'https://zenodo.org/record/7774788/files/PZT_2080_raw_data.h5?download=1'

# Specify the filename and the path to save the file
# filename = 'data_raw.h5'

# give the full path to the file for now because I don't want to download it again
filename = 'data_raw.h5'
save_path = '/home/julian/Alibek_BEPFM/Rapid-Fitting-BEPFM-NN/notebooks/Data'

# download the file
download_and_unzip(filename, url, save_path)
# Out:
# Using files already downloaded

# %%
data_path = save_path + '/' + filename

# instantiate the dataset object
dataset = BE_Dataset(data_path)

# print the contents of the file
dataset.print_be_tree
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Noisy_Data_1
#     ├ Noisy_Data_2
#     ├ Noisy_Data_3
#     ├ Noisy_Data_4
#     ├ Noisy_Data_5
#     ├ Noisy_Data_6
#     ├ Noisy_Data_7
#     ├ Noisy_Data_8
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Raw_Data_Reshaped
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
# ...

# %% [markdown]
# ### Plot of properties that are singular numbers

# %%
print("number of pixels: ", dataset.num_pix)
print("number of bins: ", dataset.num_bins)
print("BE center frequency: ", dataset.be_center_frequency)
print("BE bandwidth: ", dataset.be_bandwidth)
print("BE repeats: ", dataset.be_repeats)
print("number of cycles: ", dataset.num_cycles)
print("voltage steps: ", dataset.voltage_steps)
print("spectroscopic length (num_bins * voltage_steps): ", dataset.spectroscopic_length)
print("Sampling rate: ", dataset.sampling_rate)
# Got to here
# Out:
# number of pixels:  3600
# number of bins:  165
# BE center frequency:  1310000
# BE bandwidth:  200000
# BE repeats:  4
# number of cycles:  2
# voltage steps:  384
# spectroscopic length (num_bins * voltage_steps):  63360
# Sampling rate:  4000000

# %% [markdown]
# ### Plot of BE bandwidth

# %%
plt.plot(dataset.frequency_bin)
plt.title("Frequency Bins")
plt.xlabel("Bin Number")
plt.ylabel("Frequency (Hz)")


print("minimum frequency: ", dataset.frequency_bin.min())
print("maximum frequency: ", dataset.frequency_bin.max())
# Out:
# minimum frequency:  1229492.2
# maximum frequency:  1389648.5

# %%
plt.plot(dataset.be_waveform)
plt.title("BE Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
# Out:
# Text(0, 0.5, 'Voltage (V)')

# %%
dataset.spectroscopic_values.shape
# Out:
# (4, 63360)

# %%
plt.figure(figsize=(30, 5))
plt.plot(dataset.spectroscopic_values[0])

# %%
plt.plot(dataset.spectroscopic_values[1])

# %%
plt.figure(figsize=(30, 5))
plt.plot(dataset.spectroscopic_values[2])

# %%
plt.plot(dataset.spectroscopic_values[3])

# %%
plt.plot(dataset.dc_voltage)

# %%
plt.plot(dataset.get_voltage)

# %%
# Out:
# np.int64(384)
